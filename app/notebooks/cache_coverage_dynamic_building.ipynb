# %%
import random
import sys
import os

# Pobieramy ścieżkę do katalogu głównego projektu (dwa poziomy wyżej: ../..)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

# Dodajemy ją do ścieżek Pythona, jeśli jej tam nie ma
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import json

from app.testers.LLM_cache_building_tester import LlmCacheBuildingTester

with open('programming_questions.json', 'r') as f:
	data = json.load(f)

data
# Out:
# C:\Users\andrz\source\repos\BHL-solution\app\llms\gemini_llm.py:2: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# [{'original_question': 'Czym jest rekurencja?',
#   'cached_answer': 'Rekurencja to technika programistyczna, w ktĂłrej funkcja wywoĹ‚uje samÄ… siebie w celu rozwiÄ…zania problemu. Kluczowym elementem jest warunek bazowy, ktĂłry przerywa ciÄ…g wywoĹ‚aĹ„, zapobiegajÄ…c nieskoĹ„czonej pÄ™tli i przepeĹ‚nieniu stosu.',
#   'paraphrases': ['WyjaĹ›nij pojÄ™cie funkcji rekurencyjnej.',
#    'Na czym polega wywoĹ‚ywanie funkcji przez samÄ… siebie?',
#    'Jak dziaĹ‚a algorytm rekurencyjny?'],
#   'hard_negatives': ['Jak naprawiÄ‡ bĹ‚Ä…d RecursionError?',
#    'Czym rĂłĹĽni siÄ™ iteracja od rekurencji?']},
#  {'original_question': 'Jak dziaĹ‚a Garbage Collector w Javie?',
#   'cached_answer': 'Garbage Collector (GC) to proces automatycznego zarzÄ…dzania pamiÄ™ciÄ…, ktĂłry identyfikuje i usuwa obiekty, do ktĂłrych nie ma juĹĽ ĹĽadnych referencji w programie. DziaĹ‚a w tle, zwalniajÄ…c zasoby na stercie (heap), co zapobiega wyciekom pamiÄ™ci.',
#   'paraphrases': ['WyjaĹ›nij mechanizm odĹ›miecania pamiÄ™ci w JVM.',
#    'Kiedy usuwane sÄ… nieuĹĽywane obiekty w Javie?',
#    'Co robi proces GC w kontekĹ›cie zarzÄ…dzania pamiÄ™ciÄ…?'],
#   'hard_negatives': ['Jak rÄ™cznie wymusiÄ‡ uruchomienie Garbage Collectora?',
#    'Jakie sÄ… rĂłĹĽnice miÄ™dzy stosem a stertÄ…?']},
#  {'original_question': 'Co to jest REST API?',
#   'cached_answer': 'REST (Representational State Transfer) to styl architektoniczny sĹ‚uĹĽÄ…cy do komunikacji miÄ™dzy systemami komputerowymi z wykorzystaniem protokoĹ‚u HTTP. Opiera siÄ™ na bezstanowoĹ›ci, jednolitym interfejsie oraz standardowych metodach HTTP takich jak GET, POST, PUT i DELETE.',
#   'paraphrases': ['Zdefiniuj architekturÄ™ RESTful.',
#    'Na jakich zasadach opiera siÄ™ komunikacja w REST API?',
#    'Czym charakteryzujÄ… siÄ™ serwisy typu REST?'],
#   'hard_negatives': ['Jak zabezpieczyÄ‡ REST API tokenem JWT?',
#    'Czym rĂłĹĽni siÄ™ REST od SOAP?']},
#  {'original_question': 'Jaka jest rĂłĹĽnica miÄ™dzy listÄ… a krotkÄ… w Pythonie?',
#   'cached_answer': 'Podstawowa rĂłĹĽnica polega na mutowalnoĹ›ci: listy w Pythonie sÄ… mutowalne (moĹĽna je zmieniaÄ‡), natomiast krotki (tuples) sÄ… niemutowalne. Dodatkowo listy definiuje siÄ™ nawiasami kwadratowymi [], a krotki zwykĹ‚ymi ().',
#   'paraphrases': ['PorĂłwnaj list i tuple w jÄ™zyku Python.',
#    'Czy krotkÄ™ moĹĽna modyfikowaÄ‡ tak jak listÄ™?',
#    'List vs Tuple - kluczowe rĂłĹĽnice.'],
#   'hard_negatives': ['Jak przekonwertowaÄ‡ listÄ™ na krotkÄ™?',
#    'Jak posortowaÄ‡ listÄ™ w Pythonie?']},
#  {'original_question': 'Do czego sĹ‚uĹĽy polecenie git commit?',
#   'cached_answer': "Polecenie 'git commit' sĹ‚uĹĽy do zapisania zmian z obszaru staging (indeksu) do lokalnego repozytorium. Tworzy nowÄ… 'migawkÄ™' projektu wraz z opisem zmian, co pozwala na Ĺ›ledzenie historii rozwoju kodu.",
#   'paraphrases': ['Jak zatwierdziÄ‡ zmiany w repozytorium Git?',
#    'Co robi komenda commit w systemie kontroli wersji?',
#    'W jaki sposĂłb zapisaÄ‡ stan kodu w Gicie?'],
#   'hard_negatives': ['Jak cofnÄ…Ä‡ ostatni commit?',
#    'Jaka jest rĂłĹĽnica miÄ™dzy git add a git commit?']},
#  {'original_question': 'Czym jest SQL Injection?',
#   'cached_answer': 'SQL Injection to technika ataku polegajÄ…ca na wstrzykniÄ™ciu zĹ‚oĹ›liwego kodu SQL do zapytania bazodanowego przez dane wejĹ›ciowe aplikacji. Pozwala to atakujÄ…cemu na nieautoryzowany odczyt, modyfikacjÄ™ lub usuniÄ™cie danych z bazy.',
#   'paraphrases': ['Na czym polega atak wstrzykiwania kodu SQL?',
#    'WyjaĹ›nij zagroĹĽenie SQL Injection.',
#    'Jak dziaĹ‚a wstrzykiwanie zapytaĹ„ do bazy danych?'],
#   'hard_negatives': ['Jak zapobiegaÄ‡ SQL Injection w PHP?',
#    'Co to jest NoSQL?']},
#  {'original_question': 'Co oznacza akronim SOLID?',
#   'cached_answer': 'SOLID to mnemonik opisujÄ…cy piÄ™Ä‡ podstawowych zasad programowania obiektowego, ktĂłre majÄ… na celu uczynienie kodu bardziej czytelnym i Ĺ‚atwiejszym w utrzymaniu. Obejmuje zasady: Jednej OdpowiedzialnoĹ›ci, Otwarte-ZamkniÄ™te, Podstawienia Liskov, Segregacji InterfejsĂłw i OdwrĂłcenia ZaleĹĽnoĹ›ci.',
#   'paraphrases': ['WymieĹ„ 5 zasad dobrego programowania obiektowego.',
#    'Co kryje siÄ™ pod literami w skrĂłcie SOLID?',
#    'Zdefiniuj paradygmaty SOLID.'],
#   'hard_negatives': ['Na czym polega zasada Open-Closed?',
#    'Dlaczego kod powinien byÄ‡ SOLID?']},
#  {'original_question': 'Czym jest Docker?',
#   'cached_answer': 'Docker to otwarta platforma do tworzenia, wdraĹĽania i uruchamiania aplikacji w kontenerach. Konteneryzacja pozwala na zapakowanie aplikacji wraz ze wszystkimi jej zaleĹĽnoĹ›ciami, co gwarantuje jej spĂłjne dziaĹ‚anie w kaĹĽdym Ĺ›rodowisku.',
#   'paraphrases': ['Do czego sĹ‚uĹĽy platforma Docker?',
#    'WyjaĹ›nij koncepcjÄ™ konteneryzacji w Dockerze.',
#    'Co to jest Ĺ›rodowisko Docker?'],
#   'hard_negatives': ['Jak zainstalowaÄ‡ Dockera na Linuxie?',
#    'Czym rĂłĹĽni siÄ™ Docker od maszyny wirtualnej?']},
#  {'original_question': 'Co to jest zĹ‚oĹĽonoĹ›Ä‡ obliczeniowa Big O?',
#   'cached_answer': 'Notacja Big O (duĹĽe O) sĹ‚uĹĽy do opisu wydajnoĹ›ci lub zĹ‚oĹĽonoĹ›ci algorytmu. OkreĹ›la ona, jak czas wykonania lub zapotrzebowanie na pamiÄ™Ä‡ roĹ›nie w zaleĹĽnoĹ›ci od wzrostu rozmiaru danych wejĹ›ciowych (n), np. O(n) lub O(log n).',
#   'paraphrases': ['Jak mierzymy efektywnoĹ›Ä‡ algorytmĂłw?',
#    'WyjaĹ›nij notacjÄ™ duĹĽego O.',
#    'Co oznacza O(n) w kontekĹ›cie algorytmiki?'],
#   'hard_negatives': ['Jak obliczyÄ‡ zĹ‚oĹĽonoĹ›Ä‡ dla sortowania bÄ…belkowego?',
#    'KtĂłry algorytm sortowania jest najszybszy?']},
#  {'original_question': 'Na czym polega dziedziczenie w OOP?',
#   'cached_answer': 'Dziedziczenie to mechanizm programowania obiektowego, pozwalajÄ…cy jednej klasie (potomnej) przejÄ…Ä‡ cechy i metody innej klasy (bazowej). UmoĹĽliwia to ponowne wykorzystanie kodu oraz tworzenie hierarchii typĂłw.',
#   'paraphrases': ['Co to jest inheritance w programowaniu?',
#    'Jak klasa potomna przejmuje metody klasy bazowej?',
#    'WyjaĹ›nij relacjÄ™ rodzic-dziecko w klasach.'],
#   'hard_negatives': ['Co to jest wielodziedziczenie?',
#    'Czym rĂłĹĽni siÄ™ dziedziczenie od kompozycji?']},
#  {'original_question': 'Czym sÄ… Promises w JavaScript?',
#   'cached_answer': "Promise (obietnica) w JavaScript to obiekt reprezentujÄ…cy ewentualne zakoĹ„czenie (sukces lub poraĹĽkÄ™) operacji asynchronicznej oraz jej wynik. Pozwala na pisanie czystszego kodu asynchronicznego, unikajÄ…c tzw. 'callback hell'.",
#   'paraphrases': ['Jak dziaĹ‚ajÄ… Obietnice w JS?',
#    'Do czego sĹ‚uĹĽy obiekt Promise?',
#    'ObsĹ‚uga asynchronicznoĹ›ci za pomocÄ… Promise.'],
#   'hard_negatives': ['Jak zamieniÄ‡ Promise na async/await?',
#    'Co to jest Event Loop?']},
#  {'original_question': 'Co to jest klucz gĹ‚Ăłwny (Primary Key)?',
#   'cached_answer': 'Klucz gĹ‚Ăłwny to unikalny identyfikator rekordu w tabeli bazy danych. Musi on zawieraÄ‡ unikalnÄ… wartoĹ›Ä‡ dla kaĹĽdego wiersza i nie moĹĽe przyjmowaÄ‡ wartoĹ›ci NULL, co zapewnia integralnoĹ›Ä‡ danych.',
#   'paraphrases': ['Zdefiniuj Primary Key w bazach danych.',
#    'Jak jednoznacznie identyfikowaÄ‡ wiersze w SQL?',
#    'Cechy klucza gĹ‚Ăłwnego.'],
#   'hard_negatives': ['Jak dodaÄ‡ klucz obcy (Foreign Key)?',
#    'Czym rĂłĹĽni siÄ™ klucz gĹ‚Ăłwny od indeksu?']},
#  {'original_question': 'Czym jest framework React?',
#   'cached_answer': 'React to biblioteka JavaScript sĹ‚uĹĽÄ…ca do budowania interfejsĂłw uĹĽytkownika (UI), oparta na komponentach. Pozwala na tworzenie dynamicznych aplikacji typu SPA (Single Page Application) z wykorzystaniem wirtualnego DOM dla zwiÄ™kszenia wydajnoĹ›ci.',
#   'paraphrases': ['Opisz bibliotekÄ™ React.js.',
#    'Do czego sĹ‚uĹĽy technologia React od Facebooka?',
#    'Na czym polega budowanie UI w React?'],
#   'hard_negatives': ['Jak uĹĽywaÄ‡ hooka useState?',
#    'React vs Angular - co wybraÄ‡?']},
#  {'original_question': 'Co to jest CI/CD?',
#   'cached_answer': 'CI/CD (Continuous Integration / Continuous Delivery) to zbiĂłr praktyk w DevOps, polegajÄ…cych na czÄ™stym, automatycznym integrowaniu zmian w kodzie oraz ich automatycznym testowaniu i wdraĹĽaniu do Ĺ›rodowiska produkcyjnego.',
#   'paraphrases': ['WyjaĹ›nij pojÄ™cia ciÄ…gĹ‚ej integracji i ciÄ…gĹ‚ego wdraĹĽania.',
#    'Na czym polega pipeline CI/CD?',
#    'Automatyzacja wdraĹĽania oprogramowania.'],
#   'hard_negatives': ['Jak skonfigurowaÄ‡ Jenkinsa?',
#    'Jakie sÄ… najlepsze narzÄ™dzia do CI/CD?']},
#  {'original_question': 'Czym jest typowanie statyczne?',
#   'cached_answer': 'Typowanie statyczne to cecha jÄ™zyka programowania, w ktĂłrej typy zmiennych sÄ… sprawdzane w momencie kompilacji, a nie uruchamiania programu. Wymaga to zazwyczaj jawnego deklarowania typĂłw zmiennych, co pomaga wykrywaÄ‡ bĹ‚Ä™dy na wczesnym etapie.',
#   'paraphrases': ['Co oznacza, ĹĽe jÄ™zyk jest statycznie typowany?',
#    'Zalety sprawdzania typĂłw podczas kompilacji.',
#    'Definicja static typing.'],
#   'hard_negatives': ['Czym rĂłĹĽni siÄ™ typowanie statyczne od dynamicznego?',
#    'PrzykĹ‚ady jÄ™zykĂłw statycznie typowanych.']},
#  {'original_question': 'Co to jest CSS Grid?',
#   'cached_answer': 'CSS Grid Layout to dwuwymiarowy system ukĹ‚adu dla arkuszy stylĂłw CSS, ktĂłry pozwala projektowaÄ‡ zĹ‚oĹĽone ukĹ‚ady stron internetowych oparte na wierszach i kolumnach. UmoĹĽliwia precyzyjne rozmieszczanie elementĂłw bez uĹĽycia floatĂłw czy pozycjonowania.',
#   'paraphrases': ['Jak dziaĹ‚a siatka w CSS?',
#    'Do czego sĹ‚uĹĽy Grid Layout?',
#    'Tworzenie ukĹ‚adĂłw dwuwymiarowych w CSS.'],
#   'hard_negatives': ['Czym rĂłĹĽni siÄ™ Grid od Flexboxa?',
#    'Jak wyĹ›rodkowaÄ‡ diva w CSS?']},
#  {'original_question': 'WyjaĹ›nij wzorzec Singleton.',
#   'cached_answer': 'Singleton to kreacyjny wzorzec projektowy, ktĂłry gwarantuje, ĹĽe dana klasa bÄ™dzie miaĹ‚a tylko jednÄ… instancjÄ™ w caĹ‚ym programie i zapewnia globalny punkt dostÄ™pu do tej instancji.',
#   'paraphrases': ['Na czym polega wzorzec projektowy Singleton?',
#    'Jak zapewniÄ‡ istnienie tylko jednego obiektu danej klasy?',
#    'Definicja Singletona.'],
#   'hard_negatives': ['Kiedy unikaÄ‡ stosowania Singletona?',
#    'Jak zaimplementowaÄ‡ Singleton bezpieczny wÄ…tkowo?']},
#  {'original_question': 'Czym jest funkcja lambda?',
#   'cached_answer': 'Funkcja lambda to krĂłtka, anonimowa funkcja (bez nazwy), definiowana zazwyczaj w jednej linii kodu. Jest czÄ™sto uĹĽywana w miejscach, gdzie wymagana jest funkcja jako argument, np. przy operacjach na listach (map, filter).',
#   'paraphrases': ['Co to sÄ… funkcje anonimowe?',
#    'Zastosowanie wyraĹĽeĹ„ lambda w kodzie.',
#    'Jak dziaĹ‚ajÄ… lambdy?'],
#   'hard_negatives': ['Jak napisaÄ‡ lambdÄ™ w Pythonie?',
#    'Czy lambda moĹĽe mieÄ‡ wiele argumentĂłw?']},
#  {'original_question': 'Co to jest JSON?',
#   'cached_answer': 'JSON (JavaScript Object Notation) to lekki format wymiany danych, Ĺ‚atwy do czytania dla ludzi i maszyn. Opiera siÄ™ na strukturze par klucz-wartoĹ›Ä‡ oraz listach uporzÄ…dkowanych wartoĹ›ci i jest niezaleĹĽny od jÄ™zyka programowania.',
#   'paraphrases': ['Do czego sĹ‚uĹĽy format JSON?',
#    'Struktura danych JSON.',
#    'Standard wymiany danych w aplikacjach webowych.'],
#   'hard_negatives': ['Jak sparsowaÄ‡ JSON w Javie?',
#    'JSON vs XML - co lepsze?']},
#  {'original_question': 'Czym jest wskaĹşnik (pointer) w C++?',
#   'cached_answer': 'WskaĹşnik to zmienna, ktĂłra przechowuje adres pamiÄ™ci innej zmiennej, a nie samÄ… jej wartoĹ›Ä‡. UmoĹĽliwia bezpoĹ›rednie zarzÄ…dzanie pamiÄ™ciÄ…, operacje na tablicach oraz dynamicznÄ… alokacjÄ™ zasobĂłw.',
#   'paraphrases': ['Do czego sĹ‚uĹĽÄ… pointery w C++?',
#    'WyjaĹ›nij mechanizm adresowania pamiÄ™ci wskaĹşnikami.',
#    'Zmienna przechowujÄ…ca adres pamiÄ™ci.'],
#   'hard_negatives': ['Co to jest null pointer exception?',
#    'Czym rĂłĹĽni siÄ™ wskaĹşnik od referencji?']}]

# %%
questions = [question["original_question"] for question in data]
similair_questions = []

for question in data:
	for similair_question in question["paraphrases"]:
		similair_questions.append(similair_question)

print(questions, similair_questions)

similair_questions = random.choices(similair_questions, k=10)

# %%
tester = LlmCacheBuildingTester(questions, similair_questions)

tester.run()

# %%
with open('mathematical_questions.json', 'r') as f:
	mathematical_data = json.load(f)

mathematical_data

# %%
mathematical_questions = [question["original_question"] for question in mathematical_data]
mathematical_similar_questions = []

for question in mathematical_data:
    for similar_question in question["paraphrases"]:
        mathematical_similar_questions.append(similar_question)

mathematical_similar_questions = random.choices(mathematical_similar_questions, k=10)

print(mathematical_questions, mathematical_similar_questions)

# %%
math_tester = LlmCacheBuildingTester(mathematical_questions, mathematical_similar_questions)

math_tester.run()

# %%
with open('biological_questions.json', 'r') as f:
	biological_data = json.load(f)

biological_data

# %%
biological_questions = [question["original_question"] for question in biological_data]
biological_similar_questions = []

for question in biological_data:
    for similar_question in question["paraphrases"]:
        biological_similar_questions.append(similar_question)

biological_similar_questions = random.choices(biological_similar_questions, k=10)

print(biological_questions, biological_similar_questions)

# %%
bio_tester = LlmCacheBuildingTester(biological_questions, biological_similar_questions)

bio_tester.run()

# %%
with open('general_questions.json', 'r') as f:
	general_data = json.load(f)

general_data
# Out:
# [{'original_question': 'Do czego sĹ‚uĹĽy technologia?',
#   'paraphrases': ['Po co ludzie korzystajÄ… z technologii?',
#    'JakÄ… rolÄ™ peĹ‚ni technologia?',
#    'W jakim celu uĹĽywa siÄ™ technologii?']},
#  {'original_question': 'Co to jest informacja?',
#   'paraphrases': ['Czym jest informacja?',
#    'Jak moĹĽna opisaÄ‡ informacjÄ™?',
#    'Co oznacza pojÄ™cie informacji?']},
#  {'original_question': 'Dlaczego ludzie siÄ™ komunikujÄ…?',
#   'paraphrases': ['Po co ludziom komunikacja?',
#    'Dlaczego komunikacja jest potrzebna?',
#    'Z jakiego powodu ludzie siÄ™ porozumiewajÄ…?']},
#  {'original_question': 'Co to jest system?',
#   'paraphrases': ['Czym jest system?',
#    'Jak moĹĽna opisaÄ‡ system?',
#    'Co oznacza pojÄ™cie systemu?']},
#  {'original_question': 'Co to jest kultura?',
#   'paraphrases': ['Czym jest kultura?',
#    'Jak moĹĽna opisaÄ‡ kulturÄ™?',
#    'Co oznacza pojÄ™cie kultury?']},
#  {'original_question': 'Jak ludzie rozwiÄ…zujÄ… problemy?',
#   'paraphrases': ['W jaki sposĂłb rozwiÄ…zuje siÄ™ problemy?',
#    'Jak wyglÄ…da proces rozwiÄ…zywania problemĂłw?',
#    'Jak moĹĽna poradziÄ‡ sobie z problemem?']},
#  {'original_question': 'Co to jest algorytm?',
#   'paraphrases': ['Czym jest algorytm?',
#    'Jak moĹĽna wyjaĹ›niÄ‡ algorytm?',
#    'Co oznacza pojÄ™cie algorytmu?']},
#  {'original_question': 'Co to jest wiedza?',
#   'paraphrases': ['Czym jest wiedza?',
#    'Jak moĹĽna zdefiniowaÄ‡ wiedzÄ™?',
#    'Co oznacza pojÄ™cie wiedzy?']},
#  {'original_question': 'Co to jest pieniÄ…dz?',
#   'paraphrases': ['Czym jest pieniÄ…dz?',
#    'Jak moĹĽna opisaÄ‡ pieniÄ…dz?',
#    'Co oznacza pojÄ™cie pieniÄ…dza?']},
#  {'original_question': 'Dlaczego ludzie podejmujÄ… decyzje?',
#   'paraphrases': ['Po co podejmuje siÄ™ decyzje?',
#    'Z jakiego powodu ludzie muszÄ… wybieraÄ‡?',
#    'Dlaczego decyzje sÄ… potrzebne?']},
#  {'original_question': 'Co to jest komunikacja?',
#   'paraphrases': ['Czym jest komunikacja?',
#    'Na czym polega komunikacja?',
#    'Co oznacza pojÄ™cie komunikacji?']},
#  {'original_question': 'Co to jest sztuka?',
#   'paraphrases': ['Czym jest sztuka?',
#    'Jak moĹĽna opisaÄ‡ sztukÄ™?',
#    'Co oznacza pojÄ™cie sztuki?']},
#  {'original_question': 'Po co ludziom wiedza?',
#   'paraphrases': ['Dlaczego zdobywanie wiedzy jest waĹĽne?',
#    'Do czego potrzebna jest wiedza?',
#    'JakÄ… rolÄ™ peĹ‚ni wiedza w ĹĽyciu czĹ‚owieka?']},
#  {'original_question': 'Co to jest prawo?',
#   'paraphrases': ['Czym jest prawo?',
#    'Jak moĹĽna wyjaĹ›niÄ‡ pojÄ™cie prawa?',
#    'Co oznacza pojÄ™cie prawa?']},
#  {'original_question': 'Co to jest czas?',
#   'paraphrases': ['Czym jest czas?',
#    'Jak moĹĽna opisaÄ‡ czas?',
#    'Co oznacza pojÄ™cie czasu?']},
#  {'original_question': 'Co to jest gospodarka?',
#   'paraphrases': ['Czym jest gospodarka?',
#    'Jak moĹĽna opisaÄ‡ gospodarkÄ™?',
#    'Co oznacza pojÄ™cie gospodarki?']},
#  {'original_question': 'Co to jest technologia?',
#   'paraphrases': ['Czym jest technologia?',
#    'Jak moĹĽna opisaÄ‡ technologiÄ™?',
#    'Co oznacza pojÄ™cie technologii?']},
#  {'original_question': 'Co to jest etyka?',
#   'paraphrases': ['Czym jest etyka?',
#    'Czym zajmuje siÄ™ etyka?',
#    'Co oznacza pojÄ™cie etyki?']},
#  {'original_question': 'Co to jest przestrzeĹ„?',
#   'paraphrases': ['Czym jest przestrzeĹ„?',
#    'Jak moĹĽna opisaÄ‡ przestrzeĹ„?',
#    'Co oznacza pojÄ™cie przestrzeni?']},
#  {'original_question': 'Co to jest rozwĂłj?',
#   'paraphrases': ['Czym jest rozwĂłj?',
#    'Jak moĹĽna rozumieÄ‡ rozwĂłj?',
#    'Co oznacza pojÄ™cie rozwoju?']}]

# %%
general_questions = [question["original_question"] for question in general_data]
general_similar_questions = []
for question in general_data:
    for similar_question in question["paraphrases"]:
        general_similar_questions.append(similar_question)

general_similar_questions = random.choices(general_similar_questions, k=10)

print(general_questions, general_similar_questions)
# Out:
# ['Do czego sĹ‚uĹĽy technologia?', 'Co to jest informacja?', 'Dlaczego ludzie siÄ™ komunikujÄ…?', 'Co to jest system?', 'Co to jest kultura?', 'Jak ludzie rozwiÄ…zujÄ… problemy?', 'Co to jest algorytm?', 'Co to jest wiedza?', 'Co to jest pieniÄ…dz?', 'Dlaczego ludzie podejmujÄ… decyzje?', 'Co to jest komunikacja?', 'Co to jest sztuka?', 'Po co ludziom wiedza?', 'Co to jest prawo?', 'Co to jest czas?', 'Co to jest gospodarka?', 'Co to jest technologia?', 'Co to jest etyka?', 'Co to jest przestrzeĹ„?', 'Co to jest rozwĂłj?'] ['Jak moĹĽna opisaÄ‡ gospodarkÄ™?', 'Po co ludzie korzystajÄ… z technologii?', 'Na czym polega komunikacja?', 'Co oznacza pojÄ™cie prawa?', 'Z jakiego powodu ludzie muszÄ… wybieraÄ‡?', 'Jak wyglÄ…da proces rozwiÄ…zywania problemĂłw?', 'Czym zajmuje siÄ™ etyka?', 'Na czym polega komunikacja?', 'Czym jest wiedza?', 'Jak moĹĽna zdefiniowaÄ‡ wiedzÄ™?']

# %%
general_tester = LlmCacheBuildingTester(general_questions, general_similar_questions)

general_tester.run()
# Out:
# Similair question: Jak moĹĽna opisaÄ‡ gospodarkÄ™?
# Is cached: False
# Similair question: Po co ludzie korzystajÄ… z technologii?
# Is cached: True
# Similair question: Na czym polega komunikacja?
# Is cached: False
# Similair question: Co oznacza pojÄ™cie prawa?
# Is cached: False
# Similair question: Z jakiego powodu ludzie muszÄ… wybieraÄ‡?
# Is cached: True
# Similair question: Jak wyglÄ…da proces rozwiÄ…zywania problemĂłw?
# Is cached: True
# Similair question: Czym zajmuje siÄ™ etyka?
# Is cached: True
# Similair question: Na czym polega komunikacja?
# Is cached: False
# Similair question: Czym jest wiedza?
# Is cached: True
# Similair question: Jak moĹĽna zdefiniowaÄ‡ wiedzÄ™?
# Is cached: False
